# %%
import json

# %%
with open("all_inferences_scored.json", "r") as read_file:
    all_pts = json.load(read_file)
pts = [(k['location']["gps_latitude_decimal"], 
        k['location']["gps_longitude_decimal"], 
        k["score"]) for k in all_pts]

# %%
pts
# Out:
# [(38.89577777777778, -77.09906666666666, 0.3004),
#  (38.90977777777778, -77.1727138888889, 0),
#  (38.88972777777778, -77.1075361111111, 0.355),
#  (38.921661111111106, -77.15341944444445, 0.1542),
#  (38.898269444444445, -77.15695833333334, 0.2888),
#  (38.93690833333333, -77.18480000000001, 0.1792),
#  (38.889355555555554, -77.16451944444445, 0.0278),
#  (38.91674444444444, -77.15873055555556, 0),
#  (38.93926666666666, -77.13236111111111, 0.1808),
#  (38.93011111111111, -77.14641666666667, 0.25),
#  (38.94411944444444, -77.18095277777778, 0),
#  (38.94192777777778, -77.13986944444446, 0.3293),
#  (38.94705277777778, -77.17894722222222, 0),
#  (38.90004444444444, -77.07157222222222, 0),
#  (38.94931111111111, -77.16958611111112, 0),
#  (38.92337777777777, -77.15234444444445, 0.0312),
#  (38.92935277777777, -77.11943888888888, 0),
#  (38.93909444444444, -77.13655833333334, 0.0492),
#  (38.89081111111111, -77.15638055555556, 0),
#  (38.94349722222222, -77.15186944444444, 0.1971),
# ...
